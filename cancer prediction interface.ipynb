# %%
# -*- coding: utf-8 -*-

# Form implementation generated from reading ui file 'F:\karunadu internship\allotted project - Sri Varshni K S\Cancer prediction\cancerpredictor.ui'
#
# Created by: PyQt5 UI code generator 5.9.2
#
# WARNING! All changes made in this file will be lost!

from PyQt5 import QtCore, QtGui, QtWidgets

class Ui_Form(object):
    def setupUi(self, Form):
        Form.setObjectName("Form")
        Form.resize(998, 604)
        self.label_2 = QtWidgets.QLabel(Form)
        self.label_2.setGeometry(QtCore.QRect(310, 0, 361, 41))
        self.label_2.setStyleSheet("font: 81 22pt \"Rockwell Extra Bold\";\n"
"COLOR:rgb(150, 50, 150)")
        self.label_2.setObjectName("label_2")
        self.label_3 = QtWidgets.QLabel(Form)
        self.label_3.setGeometry(QtCore.QRect(410, 50, 51, 16))
        self.label_3.setStyleSheet("font: 87 14pt \"Arial Black\";\n"
"color:rgb(0, 0, 0)")
        self.label_3.setObjectName("label_3")
        self.label_4 = QtWidgets.QLabel(Form)
        self.label_4.setGeometry(QtCore.QRect(10, 80, 121, 31))
        self.label_4.setStyleSheet("font: 12pt \"Imprint MT Shadow\";\n"
"color:rgb(0, 0, 127)")
        self.label_4.setObjectName("label_4")
        self.label_5 = QtWidgets.QLabel(Form)
        self.label_5.setGeometry(QtCore.QRect(10, 130, 101, 21))
        self.label_5.setStyleSheet("font: 12pt \"Imprint MT Shadow\";\n"
"color:rgb(0, 0, 127)")
        self.label_5.setObjectName("label_5")
        self.label_6 = QtWidgets.QLabel(Form)
        self.label_6.setGeometry(QtCore.QRect(340, 170, 141, 21))
        self.label_6.setStyleSheet("font: 12pt \"Imprint MT Shadow\";\n"
"color:rgb(0, 0, 127)")
        self.label_6.setObjectName("label_6")
        self.label_7 = QtWidgets.QLabel(Form)
        self.label_7.setGeometry(QtCore.QRect(10, 450, 171, 21))
        self.label_7.setStyleSheet("font: 12pt \"Imprint MT Shadow\";\n"
"color:rgb(0, 0, 127)")
        self.label_7.setObjectName("label_7")
        self.label_8 = QtWidgets.QLabel(Form)
        self.label_8.setGeometry(QtCore.QRect(10, 370, 161, 21))
        self.label_8.setStyleSheet("font: 12pt \"Imprint MT Shadow\";\n"
"color:rgb(0, 0, 127)")
        self.label_8.setObjectName("label_8")
        self.label_9 = QtWidgets.QLabel(Form)
        self.label_9.setGeometry(QtCore.QRect(660, 130, 141, 21))
        self.label_9.setStyleSheet("font: 12pt \"Imprint MT Shadow\";\n"
"color:rgb(0, 0, 127)")
        self.label_9.setObjectName("label_9")
        self.label_10 = QtWidgets.QLabel(Form)
        self.label_10.setGeometry(QtCore.QRect(10, 330, 141, 21))
        self.label_10.setStyleSheet("font: 12pt \"Imprint MT Shadow\";\n"
"color:rgb(0, 0, 127)")
        self.label_10.setObjectName("label_10")
        self.label_11 = QtWidgets.QLabel(Form)
        self.label_11.setGeometry(QtCore.QRect(10, 210, 81, 21))
        self.label_11.setStyleSheet("font: 12pt \"Imprint MT Shadow\";\n"
"color:rgb(0, 0, 127)")
        self.label_11.setObjectName("label_11")
        self.label_12 = QtWidgets.QLabel(Form)
        self.label_12.setGeometry(QtCore.QRect(340, 210, 71, 20))
        self.label_12.setStyleSheet("font: 12pt \"Imprint MT Shadow\";\n"
"color:rgb(0, 0, 127)")
        self.label_12.setObjectName("label_12")
        self.label_13 = QtWidgets.QLabel(Form)
        self.label_13.setGeometry(QtCore.QRect(660, 90, 131, 21))
        self.label_13.setStyleSheet("font: 12pt \"Imprint MT Shadow\";\n"
"color:rgb(0, 0, 127)")
        self.label_13.setObjectName("label_13")
        self.label_14 = QtWidgets.QLabel(Form)
        self.label_14.setGeometry(QtCore.QRect(10, 410, 141, 21))
        self.label_14.setStyleSheet("font: 12pt \"Imprint MT Shadow\";\n"
"color:rgb(0, 0, 127)")
        self.label_14.setObjectName("label_14")
        self.label_15 = QtWidgets.QLabel(Form)
        self.label_15.setGeometry(QtCore.QRect(340, 90, 91, 21))
        self.label_15.setStyleSheet("font: 12pt \"Imprint MT Shadow\";\n"
"color:rgb(0, 0, 127)")
        self.label_15.setObjectName("label_15")
        self.label_16 = QtWidgets.QLabel(Form)
        self.label_16.setGeometry(QtCore.QRect(340, 290, 141, 20))
        self.label_16.setStyleSheet("font: 12pt \"Imprint MT Shadow\";\n"
"color:rgb(0, 0, 127)")
        self.label_16.setObjectName("label_16")
        self.label_17 = QtWidgets.QLabel(Form)
        self.label_17.setGeometry(QtCore.QRect(10, 250, 131, 21))
        self.label_17.setStyleSheet("font: 12pt \"Imprint MT Shadow\";\n"
"color:rgb(0, 0, 127)")
        self.label_17.setObjectName("label_17")
        self.label_18 = QtWidgets.QLabel(Form)
        self.label_18.setGeometry(QtCore.QRect(660, 250, 161, 21))
        self.label_18.setStyleSheet("font: 12pt \"Imprint MT Shadow\";\n"
"color:rgb(0, 0, 127)")
        self.label_18.setObjectName("label_18")
        self.label_19 = QtWidgets.QLabel(Form)
        self.label_19.setGeometry(QtCore.QRect(340, 130, 131, 21))
        self.label_19.setStyleSheet("font: 12pt \"Imprint MT Shadow\";\n"
"color:rgb(0, 0, 127)")
        self.label_19.setObjectName("label_19")
        self.label_20 = QtWidgets.QLabel(Form)
        self.label_20.setGeometry(QtCore.QRect(660, 330, 141, 21))
        self.label_20.setStyleSheet("font: 12pt \"Imprint MT Shadow\";\n"
"color:rgb(0, 0, 127)")
        self.label_20.setObjectName("label_20")
        self.label_21 = QtWidgets.QLabel(Form)
        self.label_21.setGeometry(QtCore.QRect(340, 410, 121, 21))
        self.label_21.setStyleSheet("font: 12pt \"Imprint MT Shadow\";\n"
"color:rgb(0, 0, 127)")
        self.label_21.setObjectName("label_21")
        self.label_22 = QtWidgets.QLabel(Form)
        self.label_22.setGeometry(QtCore.QRect(660, 450, 181, 21))
        self.label_22.setStyleSheet("font: 12pt \"Imprint MT Shadow\";\n"
"color:rgb(0, 0, 127)")
        self.label_22.setObjectName("label_22")
        self.label_23 = QtWidgets.QLabel(Form)
        self.label_23.setGeometry(QtCore.QRect(340, 320, 121, 31))
        self.label_23.setStyleSheet("font: 12pt \"Imprint MT Shadow\";\n"
"color:rgb(0, 0, 127)")
        self.label_23.setObjectName("label_23")
        self.label_24 = QtWidgets.QLabel(Form)
        self.label_24.setGeometry(QtCore.QRect(660, 170, 121, 21))
        self.label_24.setStyleSheet("font: 12pt \"Imprint MT Shadow\";\n"
"color:rgb(0, 0, 127)")
        self.label_24.setObjectName("label_24")
        self.label_25 = QtWidgets.QLabel(Form)
        self.label_25.setGeometry(QtCore.QRect(10, 170, 151, 21))
        self.label_25.setStyleSheet("font: 12pt \"Imprint MT Shadow\";\n"
"color:rgb(0, 0, 127)")
        self.label_25.setObjectName("label_25")
        self.label_26 = QtWidgets.QLabel(Form)
        self.label_26.setGeometry(QtCore.QRect(290, 570, 121, 31))
        self.label_26.setStyleSheet("font: 87 14pt \"Arial Black\";\n"
"color:rgb(0,0,0)")
        self.label_26.setObjectName("label_26")
        self.label_27 = QtWidgets.QLabel(Form)
        self.label_27.setGeometry(QtCore.QRect(340, 450, 181, 21))
        self.label_27.setStyleSheet("font: 12pt \"Imprint MT Shadow\";\n"
"color:rgb(0, 0, 127)")
        self.label_27.setObjectName("label_27")
        self.label_28 = QtWidgets.QLabel(Form)
        self.label_28.setGeometry(QtCore.QRect(340, 250, 141, 21))
        self.label_28.setStyleSheet("font: 12pt \"Imprint MT Shadow\";\n"
"color:rgb(0, 0, 127)")
        self.label_28.setObjectName("label_28")
        self.label_29 = QtWidgets.QLabel(Form)
        self.label_29.setGeometry(QtCore.QRect(340, 370, 151, 21))
        self.label_29.setStyleSheet("font: 12pt \"Imprint MT Shadow\";\n"
"color:rgb(0, 0, 127)")
        self.label_29.setObjectName("label_29")
        self.label_30 = QtWidgets.QLabel(Form)
        self.label_30.setGeometry(QtCore.QRect(10, 290, 131, 21))
        self.label_30.setStyleSheet("font: 12pt \"Imprint MT Shadow\";\n"
"color:rgb(0, 0, 127)")
        self.label_30.setObjectName("label_30")
        self.label_32 = QtWidgets.QLabel(Form)
        self.label_32.setGeometry(QtCore.QRect(660, 290, 171, 21))
        self.label_32.setStyleSheet("font: 12pt \"Imprint MT Shadow\";\n"
"color:rgb(0, 0, 127)")
        self.label_32.setObjectName("label_32")
        self.label_33 = QtWidgets.QLabel(Form)
        self.label_33.setGeometry(QtCore.QRect(660, 210, 111, 21))
        self.label_33.setStyleSheet("font: 12pt \"Imprint MT Shadow\";\n"
"color:rgb(0, 0, 127)")
        self.label_33.setObjectName("label_33")
        self.label_34 = QtWidgets.QLabel(Form)
        self.label_34.setGeometry(QtCore.QRect(660, 370, 161, 21))
        self.label_34.setStyleSheet("font: 12pt \"Imprint MT Shadow\";\n"
"color:rgb(0, 0, 127)")
        self.label_34.setObjectName("label_34")
        self.label_35 = QtWidgets.QLabel(Form)
        self.label_35.setGeometry(QtCore.QRect(660, 410, 151, 21))
        self.label_35.setStyleSheet("font: 12pt \"Imprint MT Shadow\";\n"
"color:rgb(0, 0, 127)")
        self.label_35.setObjectName("label_35")
        self.txtid = QtWidgets.QLineEdit(Form)
        self.txtid.setGeometry(QtCore.QRect(450, 50, 113, 20))
        self.txtid.setStyleSheet("font: 11pt \"Franklin Gothic Demi\";\n"
"color: rgb(0, 85, 0);")
        self.txtid.setObjectName("txtid")
        self.txtperimeter_mean = QtWidgets.QLineEdit(Form)
        self.txtperimeter_mean.setGeometry(QtCore.QRect(200, 170, 113, 20))
        self.txtperimeter_mean.setObjectName("txtperimeter_mean")
        self.txtconcavity_mean = QtWidgets.QLineEdit(Form)
        self.txtconcavity_mean.setGeometry(QtCore.QRect(200, 330, 113, 20))
        self.txtconcavity_mean.setObjectName("txtconcavity_mean")
        self.txtradius_se = QtWidgets.QLineEdit(Form)
        self.txtradius_se.setGeometry(QtCore.QRect(510, 90, 113, 20))
        self.txtradius_se.setStyleSheet("font: 11pt \"Franklin Gothic Demi\";\n"
"color: rgb(0, 85, 0);")
        self.txtradius_se.setObjectName("txtradius_se")
        self.txtsmoothness_se = QtWidgets.QLineEdit(Form)
        self.txtsmoothness_se.setGeometry(QtCore.QRect(510, 250, 113, 20))
        self.txtsmoothness_se.setObjectName("txtsmoothness_se")
        self.txtcompactness_se = QtWidgets.QLineEdit(Form)
        self.txtcompactness_se.setGeometry(QtCore.QRect(510, 290, 113, 20))
        self.txtcompactness_se.setObjectName("txtcompactness_se")
        self.txtfractal_dimension_se = QtWidgets.QLineEdit(Form)
        self.txtfractal_dimension_se.setGeometry(QtCore.QRect(510, 450, 113, 20))
        self.txtfractal_dimension_se.setObjectName("txtfractal_dimension_se")
        self.txtarea_worst = QtWidgets.QLineEdit(Form)
        self.txtarea_worst.setGeometry(QtCore.QRect(860, 210, 113, 20))
        self.txtarea_worst.setObjectName("txtarea_worst")
        self.txtconcavepoints_worst = QtWidgets.QLineEdit(Form)
        self.txtconcavepoints_worst.setGeometry(QtCore.QRect(860, 370, 113, 20))
        self.txtconcavepoints_worst.setObjectName("txtconcavepoints_worst")
        self.txtsmoothness_worst = QtWidgets.QLineEdit(Form)
        self.txtsmoothness_worst.setGeometry(QtCore.QRect(860, 250, 113, 20))
        self.txtsmoothness_worst.setObjectName("txtsmoothness_worst")
        self.txtradius_mean = QtWidgets.QLineEdit(Form)
        self.txtradius_mean.setGeometry(QtCore.QRect(200, 90, 113, 20))
        self.txtradius_mean.setStyleSheet("font: 11pt \"Franklin Gothic Demi\";\n"
"color: rgb(0, 85, 0);")
        self.txtradius_mean.setObjectName("txtradius_mean")
        self.txtsmoothness_mean = QtWidgets.QLineEdit(Form)
        self.txtsmoothness_mean.setGeometry(QtCore.QRect(200, 250, 113, 20))
        self.txtsmoothness_mean.setObjectName("txtsmoothness_mean")
        self.txtsymmetry_mean = QtWidgets.QLineEdit(Form)
        self.txtsymmetry_mean.setGeometry(QtCore.QRect(200, 410, 113, 20))
        self.txtsymmetry_mean.setObjectName("txtsymmetry_mean")
        self.txtperimeter_se = QtWidgets.QLineEdit(Form)
        self.txtperimeter_se.setGeometry(QtCore.QRect(510, 170, 113, 20))
        self.txtperimeter_se.setObjectName("txtperimeter_se")
        self.txtconcavepoints_se = QtWidgets.QLineEdit(Form)
        self.txtconcavepoints_se.setGeometry(QtCore.QRect(510, 370, 113, 20))
        self.txtconcavepoints_se.setObjectName("txtconcavepoints_se")
        self.txttexture_worst = QtWidgets.QLineEdit(Form)
        self.txttexture_worst.setGeometry(QtCore.QRect(860, 130, 113, 20))
        self.txttexture_worst.setObjectName("txttexture_worst")
        self.txtcompactness_worst = QtWidgets.QLineEdit(Form)
        self.txtcompactness_worst.setGeometry(QtCore.QRect(860, 290, 113, 20))
        self.txtcompactness_worst.setObjectName("txtcompactness_worst")
        self.txtconcavepoints_mean = QtWidgets.QLineEdit(Form)
        self.txtconcavepoints_mean.setGeometry(QtCore.QRect(200, 370, 113, 20))
        self.txtconcavepoints_mean.setObjectName("txtconcavepoints_mean")
        self.txtsymmetry_worst = QtWidgets.QLineEdit(Form)
        self.txtsymmetry_worst.setGeometry(QtCore.QRect(860, 410, 113, 20))
        self.txtsymmetry_worst.setObjectName("txtsymmetry_worst")
        self.txtradius_worst = QtWidgets.QLineEdit(Form)
        self.txtradius_worst.setGeometry(QtCore.QRect(860, 90, 113, 20))
        self.txtradius_worst.setStyleSheet("font: 11pt \"Franklin Gothic Demi\";\n"
"color: rgb(0, 85, 0);")
        self.txtradius_worst.setObjectName("txtradius_worst")
        self.txtconcavity_se = QtWidgets.QLineEdit(Form)
        self.txtconcavity_se.setGeometry(QtCore.QRect(510, 330, 113, 20))
        self.txtconcavity_se.setObjectName("txtconcavity_se")
        self.txttexture_mean = QtWidgets.QLineEdit(Form)
        self.txttexture_mean.setGeometry(QtCore.QRect(200, 130, 113, 20))
        self.txttexture_mean.setObjectName("txttexture_mean")
        self.txtcompactness_mean = QtWidgets.QLineEdit(Form)
        self.txtcompactness_mean.setGeometry(QtCore.QRect(200, 290, 113, 20))
        self.txtcompactness_mean.setObjectName("txtcompactness_mean")
        self.txtfractal_dimension_mean = QtWidgets.QLineEdit(Form)
        self.txtfractal_dimension_mean.setGeometry(QtCore.QRect(200, 450, 113, 20))
        self.txtfractal_dimension_mean.setObjectName("txtfractal_dimension_mean")
        self.txtarea_se = QtWidgets.QLineEdit(Form)
        self.txtarea_se.setGeometry(QtCore.QRect(510, 210, 113, 20))
        self.txtarea_se.setObjectName("txtarea_se")
        self.txttexture_se = QtWidgets.QLineEdit(Form)
        self.txttexture_se.setGeometry(QtCore.QRect(510, 130, 113, 20))
        self.txttexture_se.setObjectName("txttexture_se")
        self.txtsymmetry_se = QtWidgets.QLineEdit(Form)
        self.txtsymmetry_se.setGeometry(QtCore.QRect(510, 410, 113, 20))
        self.txtsymmetry_se.setObjectName("txtsymmetry_se")
        self.txtperimeter_worst = QtWidgets.QLineEdit(Form)
        self.txtperimeter_worst.setGeometry(QtCore.QRect(860, 170, 113, 20))
        self.txtperimeter_worst.setObjectName("txtperimeter_worst")
        self.txtconcavity_worst = QtWidgets.QLineEdit(Form)
        self.txtconcavity_worst.setGeometry(QtCore.QRect(860, 330, 113, 20))
        self.txtconcavity_worst.setObjectName("txtconcavity_worst")
        self.txtarea_mean = QtWidgets.QLineEdit(Form)
        self.txtarea_mean.setGeometry(QtCore.QRect(200, 210, 113, 20))
        self.txtarea_mean.setObjectName("txtarea_mean")
        self.txtfractal_dimension_worst = QtWidgets.QLineEdit(Form)
        self.txtfractal_dimension_worst.setGeometry(QtCore.QRect(860, 450, 113, 20))
        self.txtfractal_dimension_worst.setObjectName("txtfractal_dimension_worst")
        self.btnperformdiagnosis = QtWidgets.QPushButton(Form)
        self.btnperformdiagnosis.setGeometry(QtCore.QRect(420, 510, 201, 41))
        self.btnperformdiagnosis.setStyleSheet("font: 87 12pt \"Arial Black\";\n"
"color:rgb(255, 0, 127)")
        self.btnperformdiagnosis.setObjectName("btnperformdiagnosis")
        self.txtdiagnosis = QtWidgets.QLabel(Form)
        self.txtdiagnosis.setGeometry(QtCore.QRect(410, 570, 161, 31))
        self.txtdiagnosis.setStyleSheet("font: 20pt \"Tw Cen MT Condensed Extra Bold\";\n"
"color: rgb(170, 0, 0)")
        self.txtdiagnosis.setObjectName("txtdiagnosis")
        self.label_36 = QtWidgets.QLabel(Form)
        self.label_36.setGeometry(QtCore.QRect(890, 540, 121, 31))
        self.label_36.setStyleSheet("font: 87 10pt \"Segoe UI Black\";\n"
"color:rgb(0, 85, 0)")
        self.label_36.setObjectName("label_36")
        self.label_37 = QtWidgets.QLabel(Form)
        self.label_37.setGeometry(QtCore.QRect(890, 580, 71, 16))
        self.label_37.setStyleSheet("font: 87 10pt \"Segoe UI Black\";\n"
"color:rgb(0, 85, 0)")
        self.label_37.setObjectName("label_37")

        self.retranslateUi(Form)
        QtCore.QMetaObject.connectSlotsByName(Form)

    def retranslateUi(self, Form):
        _translate = QtCore.QCoreApplication.translate
        Form.setWindowTitle(_translate("Form", "cancer predictor"))
        self.label_2.setText(_translate("Form", "CANCER PREDICTOR"))
        self.label_3.setText(_translate("Form", "id:"))
        self.label_4.setText(_translate("Form", "radius_mean"))
        self.label_5.setText(_translate("Form", "texture_mean"))
        self.label_6.setText(_translate("Form", "perimeter_se"))
        self.label_7.setText(_translate("Form", "fractal_dimension_mean"))
        self.label_8.setText(_translate("Form", "concave points_mean"))
        self.label_9.setText(_translate("Form", "texture_worst"))
        self.label_10.setText(_translate("Form", "concavity_mean"))
        self.label_11.setText(_translate("Form", "area_mean"))
        self.label_12.setText(_translate("Form", "area_se"))
        self.label_13.setText(_translate("Form", "radius_worst"))
        self.label_14.setText(_translate("Form", "symmetry_mean"))
        self.label_15.setText(_translate("Form", "radius_se"))
        self.label_16.setText(_translate("Form", "compactness_se"))
        self.label_17.setText(_translate("Form", "smoothness_mean"))
        self.label_18.setText(_translate("Form", "smoothness_worst"))
        self.label_19.setText(_translate("Form", "texture_se"))
        self.label_20.setText(_translate("Form", "concavity_worst"))
        self.label_21.setText(_translate("Form", "symmetry_se"))
        self.label_22.setText(_translate("Form", "fractal_dimension_worst"))
        self.label_23.setText(_translate("Form", "concavity_se"))
        self.label_24.setText(_translate("Form", "perimeter_worst"))
        self.label_25.setText(_translate("Form", "perimeter_mean"))
        self.label_26.setText(_translate("Form", "diagnosis:"))
        self.label_27.setText(_translate("Form", "fractal_dimension_se"))
        self.label_28.setText(_translate("Form", "smoothness_se"))
        self.label_29.setText(_translate("Form", "concave points_se"))
        self.label_30.setText(_translate("Form", "compactness_mean"))
        self.label_32.setText(_translate("Form", "compactness_worst"))
        self.label_33.setText(_translate("Form", "area_worst"))
        self.label_34.setText(_translate("Form", "concave points_worst"))
        self.label_35.setText(_translate("Form", "symmetry_worst"))
        self.btnperformdiagnosis.setText(_translate("Form", "Perform Diagnosis"))
        self.txtdiagnosis.setText(_translate("Form", "TextLabel"))
        self.label_36.setText(_translate("Form", "M - Malignant"))
        self.label_37.setText(_translate("Form", "B - Benign"))


if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    Form = QtWidgets.QWidget()
    ui = Ui_Form()
    ui.setupUi(Form)
    Form.show()
    sys.exit(app.exec_())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# C:\Users\USER\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3445: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
